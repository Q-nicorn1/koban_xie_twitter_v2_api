# %%
import api_wrapper as api
import os
import pandas as pd

# %% [markdown]
# ### 1. Set the `BEARER_TOKEN` variable to your developer bearer token.

# %%
token = pd.read_csv("/Users/dankoban/Documents/EM6586_DB_Management/bearer_token.csv")
os.environ["BEARER_TOKEN"] = token['token'][0]

# %% [markdown]
# ### 2. Query user profile info

# %%
usernames = ['Broniatowski']
user_info = api.get_users(usernames=usernames)
user_info
# Out:
#      user_id      username                   name  \
# 0  195572533  Broniatowski  David A. Broniatowski
#
#                                          description        location  \
# 0  Professor at The George Washington University ...  Washington, DC
#
#                  created_at  followers_count  following_count  tweet_count  \
# 0  2010-09-27T01:39:27.000Z            260.0            274.0        242.0
#
#    listed_count
# 0           3.0

# %% [markdown]
# ### 3. Query user to determine which accounts they follow

# %%
followed_accounts = api.lookup_followed_accounts('Broniatowski', record_count = 300)
followed_accounts.head()
# Out:
# token: LQVNGQCCBHVHEZZZ
# token: 5F70OBN0EDA1EZZZ
# token: 3UGFB5LDV4A1EZZZ
#                user_id        username  \
# 0  1348984952768094210       YearCovid
# 1            277495248  IrenePasquetto
# 2   770729895374708736    KolinaKoltai
# 3            613537091         NNLMPSR
# 4            607381756     HuiWen_Chan
#
#                                                 name  \
# 0                                 Covid One Year Ago
# 1                                    Irene Pasquetto
# 2                                 Kolina Koltai, PhD
# 3  Network of the National Library of Medicine - PSR
# 4                                       Hui Wen Chan
#
#                                          description         location  \
# 0  Livetweeting the covid pandemic as it happened...              NaN
# 1  Information / infrastructures / epistemology. ...       Boston, MA
# 2  Postdoc at @uwcip. PhD from @utischool. Resear...      Seattle, WA
# 3  NNLM PSR serves the biomedical information nee...  Los Angeles, CA
# 4                                                                 NaN
#
#                  created_at  followers_count  following_count  tweet_count  \
# 0  2021-01-12T13:28:06.000Z          40438.0              0.0        135.0
# 1  2011-04-05T13:54:39.000Z           1505.0            488.0       4096.0
# 2  2016-08-30T21:08:21.000Z           1784.0            959.0       2366.0
# 3  2012-06-20T15:48:18.000Z            558.0            337.0      11964.0
# 4  2012-06-13T17:08:47.000Z            136.0            104.0        119.0
#
#    listed_count
# 0         235.0
# 1          65.0
# 2          45.0
# 3          74.0
# 4           8.0

# %%
misinfo_researchers = ['Broniatowski','IrenePasquetto','KolinaKoltai','uwcip','sarahshirazyan','nataschachtena',
 'nadiabrashier','disinformediain','jayvanbavel','lkfazio','STWorg','yang3kc','DG_Rand','_mohsen_m','KaiShu0327',
 'GWIDDP','yangyunkang','redheadacademic','marco_zenone','sinanaral','davidlazer','az_jacobs','PedramHosseini',
 'AMJAMAMJAM1','emmaspiro','psychunseen','MattHindman','Briony_Swire','lylengyan','emilio__ferrara','Graphika_NYC',
 'naomishiffman','katestarbird','noUpside','LeticiaBode','ekvraga','RebekahKTromble','gmukunda',
 'jonathan_c_ong', 'EthanVPorter','GordPennycook']
followed_accounts[followed_accounts['username'].isin(misinfo_researchers)]
# Out:
#                 user_id         username  \
# 1             277495248   IrenePasquetto
# 2    770729895374708736     KolinaKoltai
# 19  1149023588818624512            uwcip
# 27           1221415440   sarahshirazyan
# 32            215374612   nataschachtena
# 39            131623639   jonathan_c_ong
# 49   998783211319844865    nadiabrashier
# 50  1088512998493294592  disinformediain
# 54            285698560      jayvanbavel
# 60   868583493428752389          lkfazio
# 66            277826494           STWorg
# 67  1133069780917850112          yang3kc
# 68            605012771          DG_Rand
# 69  1260526934678740993        _mohsen_m
# 70  1128095824473276418       KaiShu0327
# 94  1194654661447434243           GWIDDP
# 0             164878430      yangyunkang
# 10           1641558816  redheadacademic
# 11  1038599418797219840     marco_zenone
# 21            214272214        sinanaral
# 30             76122505     EthanVPorter
# 32           3081982205    GordPennycook
# 34             37213193       davidlazer
# 40            579143740        az_jacobs
# 42            100534711   PedramHosseini
# 43  1266474458384130051      AMJAMAMJAM1
# 44           1384800560        emmaspiro
# 46           3252879229      psychunseen
# 51             65756735      MattHindman
# 61           2806065448     Briony_Swire
# 64           1695363828        lylengyan
# 68             17354555  emilio__ferrara
# 71           3064684991     Graphika_NYC
# 90            526584444    naomishiffman
# 99             19203768     katestarbird
# 1              24254084         noUpside
# 6             285236647      LeticiaBode
# 7              14209342          ekvraga
# 11           2288017969  RebekahKTromble
# 49             80356272         gmukunda
#
#                                         name  \
# 1                            Irene Pasquetto
# 2                         Kolina Koltai, PhD
# 19             Center for an Informed Public
# 27                           Sarah Shirazyan
# 32                           Natascha Chtena
# 39                       Jonathan Corpus Ong
# 49                            Nadia Brashier
# 50                         Iain | he/him/his
# 54                             Jay Van Bavel
# 60                                Lisa Fazio
# 66                       Stephan Lewandowsky
# 67                                Kevin Yang
# 68                             David G. Rand
# 69                             Mohsen Mosleh
# 70                                   Kai Shu
# 94  Institute for Data, Democracy & Politics
# 0                          Yunkang Yang, PhD
# 10                        Dr. Jeanine Guidry
# 11                         Marco Zenone, MSc
# 21                                Sinan Aral
# 30                              Ethan Porter
# 32                          Gordon Pennycook
# 34                               David Lazer
# 40                            Abigail Jacobs
# 42                           Pedram Hosseini
# 43                         Amelia M. Jamison
# 44                                Emma Spiro
# 46                            Joe Pierre, MD
# 51                           Matthew Hindman
# 61                     Briony Swire-Thompson
# 64                                  Yan Leng
# 68                            Emilio Ferrara
# 71                                  Graphika
# 90                            Naomi Shiffman
# 99                             Kate Starbird
# 1                              Renee DiResta
# 6                               Leticia Bode
# 7                            Dr. Emily Vraga
# 11                       Dr. Rebekah Tromble
# 49                            Gautam Mukunda
#
#                                           description  \
# 1   Information / infrastructures / epistemology. ...
# 2   Postdoc at @uwcip. PhD from @utischool. Resear...
# 19  University of Washington research center. Resi...
# 27  Misinformation|Content Policy. Lecturer in Law...
# 32  Editor-in-Chief at the HKS Misinformation Revi...
# 39  Associate Professor of Global Digital Media, U...
# 49  Postdoc @Harvard studying how people judge tru...
# 50  Deputy Managing Editor, @DFRLab. #Disinfo #Dig...
# 54  Social neuroscience professor at NYU writing a...
# 60  Assistant professor at Vanderbilt University, ...
# 66  Prof Stephan Lewandowsky School of Psychology ...
# 67  Computational social science | network science...
# 68  Prof at MIT. Working on misinformation/fake ne...
# 69  Prof of Business Analytics @UniofExeter, Resea...
# 70  CS Faculty @illinoistech; Ph.D. of CS in @ASUE...
# 44                  Seattle, WA  2013-04-27T15:57:58.000Z           1230.0
# 46              Los Angeles, CA  2015-06-22T15:52:02.000Z           5597.0
# 51               Washington, DC  2009-08-14T22:43:02.000Z           1560.0
# 61                          NaN  2014-10-04T18:51:55.000Z            591.0
# 64                Cambridge, MA  2013-08-24T03:08:21.000Z            451.0
# 68              Los Angeles, CA  2008-11-13T02:11:01.000Z          27194.0
# 71                 New York, NY  2015-02-28T04:48:36.000Z           7754.0
# 90                 Berkeley, CA  2012-03-16T16:55:05.000Z            626.0
# 99                  Seattle, WA  2009-01-19T21:43:21.000Z          38508.0
# 1             San Francisco, CA  2009-03-13T21:06:13.000Z          58642.0
# 6                           NaN  2011-04-20T19:46:55.000Z           3081.0
# 7               Minneapolis, MN  2008-03-24T18:08:33.000Z           2256.0
# 11                       🇺🇸🇳🇱🇩🇪  2014-01-12T10:55:16.000Z           3377.0
# 49                   Boston, MA  2009-10-06T17:32:32.000Z           8448.0
#
#     following_count  tweet_count  listed_count
# 1             488.0       4096.0          65.0
# 2             959.0       2366.0          45.0
# 19            352.0       1017.0         123.0
# 27            580.0        115.0           6.0
# 32            930.0       1198.0          16.0
# 39           1686.0       5939.0          66.0
# 49            926.0        792.0          37.0
# 50            563.0       1883.0          25.0
# 54            710.0       8711.0         620.0
# 60           2155.0       4772.0          55.0
# 66           1746.0      15286.0         221.0
# 67            363.0        414.0           3.0
# 68           1209.0       7148.0         320.0
# 69            230.0         90.0           6.0
# 70            205.0         99.0           6.0
# 94            402.0        471.0          18.0
# 0             243.0        133.0           2.0
# 10           2236.0       2178.0          53.0
# 11            685.0        659.0           0.0
# 21           9855.0      11447.0        1053.0
# 30            953.0       1477.0          53.0
# 32           1887.0       9755.0         139.0
# 34           3093.0      18125.0         485.0
# 40           1741.0        471.0          65.0
# 42            271.0        288.0           2.0
# 43            153.0         60.0           2.0
# 44            872.0        243.0          59.0
# 46           3131.0      10582.0          60.0
# 51           1096.0       1863.0          69.0
# 61            374.0         56.0          21.0
# 64            240.0        133.0           8.0
# 68           1118.0      11951.0        1225.0
# 71           1879.0       2679.0         436.0
# 90            771.0       1004.0          12.0
# 99           3367.0      18997.0        1153.0
# 1            1248.0      24494.0        1697.0
# 6            1045.0       7092.0         157.0
# 7             876.0       5126.0         119.0
# 11           1394.0       5358.0          73.0
# 49           4447.0       1215.0         267.0

# %% [markdown]
# ### 4. Query user activity for last 200 posts

# %%
activity = api.get_user_activity(usernames=misinfo_researchers, record_count = 200)
print(len(activity))
activity.head()
# Out:
# token: 7140dibdnow9c7btw3w3j88qre80ptq05u8x44vw65mif
# token: 7140dibdnow9c7btw3w29gs6js0q20ogewivd78kmy5h1
# token: 7140dibdnow9c7btw3w3j89xylx3uyka54p02tj43r511
# token: 7140dibdnow9c7btw3t46fnuz15ktjtc7r5nztfb9vc4w
# token: 7140dibdnow9c7btw3w3j89xx20jp7ec1gvho71ft4yt4
# token: 7140dibdnow9c7btw3w33u3lmnhqcp99o9008mg62lx6f
# token: 7140dibdnow9c7btw3w3j88qxf7t5gl75qn1u69ffe7g8
# token: 7140dibdnow9c7btw3w3xun926ezuvnmiujo57zyl8ugm
# token: 7140dibdnow9c7btw3w3j1v5w8nt0cp91rilsip0jqzhx
# token: 7140dibdnow9c7btw3w3ixmb4wfw4878c9wdtjm2qk9x1
# token: 7140dibdnow9c7btw3w29acszlh48oyeee8r898rmzkfo
# token: 7140dibdnow9c7btw3w29rg45xpz7ur713x25jqasunna
# token: 7140dibdnow9c7btw3w29n5rey07klh3i99wivrnxmvcn
# token: 7140dibdnow9c7btw3n1oi8y1xz0d57qqdztf8zhfgegl
# token: 7140dibdnow9c7btw3w3izrca8vw2zr57se1etapiwb3r
# token: 7140dibdnow9c7btw3w29ixt9zur6tg6b8urwnv173goi
# token: 7140dibdnow9c7btw3w3j3yzi7d5v43d5g21opbk8hgz4
# token: 7140dibdnow9c7btw3q34s6pg57kebcuns70xk3owssvm
# token: 7140dibdnow9c7btw3w3ixmb7x1m2rh7t2tjxvhm9gbp0
# token: 7140dibdnow9c7btw3w1u92ermq3mdbsn7fzk6gi4vtbk
# token: 7140dibdnow9c7btw3w3j89xx3idkgr218fcurzy8iwja
# token: 7140dibdnow9c7btw3w3j1uuxpy0z46s5aoldlg3tqfcj
# token: 7140dibdnow9c7btw3w3j89y35sce7zgi48c96hst22wm
# token: 7140dibdnow9c7btw3w3izq51is7zyxmdw3urnh66jd4j
# token: 7140dibdnow9c7btw3w3j89xvkgf6edfx8sivt7hnmott
# token: 7140dibdnow9c7btw3w33notb5863w0lefzkh93p9v0vq
# token: 7140dibdnow9c7btw3w3j3zvwzwgukz43ec9bf4s9lxdg
# token: 7140dibdnow9c7btw3w29n4kdsl12jbwpge32udp5ko52
# token: 7140dibdnow9c7btw3w3j8a8nz71wgxft61vdtt3xep85
# token: 7140dibdnow9c7btw3w33ycqsquf0ihrdwgsjspy9h4c2
# token: 7140dibdnow9c7btw3w3j8a8o097wc3o37m3es6u1tgl5
# token: 7140dibdnow9c7btw3w3j87ufl0l6occra93hi9ezxy5v
# token: 7140dibdnow9c7btw3w3j891jrw2apm2b8gvk0f6tjxgy
# token: 7140dibdnow9c7btw3w33w8bqfjtqpjft4jwc2our484w
# token: 7140dibdnow9c7btw3w3j89xu29b9jjm9oyt9bhqrqd6c
# token: 7140dibdnow9c7btw3w33pvxrx8vwxpyl5gcaofljxhyo
# token: 7140dibdnow9c7btw3w3j89xvj6ayyfqege89891qkks3
# token: 7140dibdnow9c7btw3w340hh141sz53w8e5o4wiv0fs4x
# 7424
#        conversation_id lang  author_id  \
# 0  1367938234773299202   en  195572533
# 1  1367664211896176641   en  195572533
# 2  1367514456893308930   en  195572533
# 3  1367133917778751488   en  195572533
# 4  1367119879246077960  und  195572533
#
#                                    referenced_tweets  \
# 0  [{'type': 'quoted', 'id': '1367923725887287302'}]
# 1  [{'type': 'quoted', 'id': '1367152280022228992'}]
# 2  [{'type': 'quoted', 'id': '1367389953227915264'}]
# 3  [{'type': 'quoted', 'id': '1367102684092841984'}]
# 4  [{'type': 'replied_to', 'id': '136711987924607...
#
#                                                 text  \
# 0  In 2008, Wired published an article entitled "...
# 1  Great insights from @redheadacademic https://t...
# 2  You can educate intuition! https://t.co/wSgDpQ...
# 3  How much of this could be explained by base ra...
# 4                     @olgs7 https://t.co/VkSpURR0Xg
#
#                                             entities  \
# 0  {'annotations': [{'start': 9, 'end': 13, 'prob...
# 1  {'mentions': [{'start': 20, 'end': 36, 'userna...
# 2  {'urls': [{'start': 27, 'end': 50, 'url': 'htt...
# 3  {'urls': [{'start': 236, 'end': 259, 'url': 'h...
# 4  {'mentions': [{'start': 0, 'end': 6, 'username...
#
#                  created_at                   id  \
# 0  2021-03-05T20:41:04.000Z  1367938234773299202
# 1  2021-03-05T02:32:12.000Z  1367664211896176641
# 2  2021-03-04T16:37:08.000Z  1367514456893308930
# 3  2021-03-03T15:25:00.000Z  1367133917778751488
# 4  2021-03-03T14:39:29.000Z  1367122463914680326
#
#                                       public_metrics in_reply_to_user_id  \
# 0  {'retweet_count': 0, 'reply_count': 0, 'like_c...                 NaN
# 1  {'retweet_count': 0, 'reply_count': 0, 'like_c...                 NaN
# 2  {'retweet_count': 0, 'reply_count': 0, 'like_c...                 NaN
# 3  {'retweet_count': 0, 'reply_count': 0, 'like_c...                 NaN
# 4  {'retweet_count': 0, 'reply_count': 0, 'like_c...            23097748
#
#   author_screen_name  geo
# 0       Broniatowski  NaN
# 1       Broniatowski  NaN
# 2       Broniatowski  NaN
# 3       Broniatowski  NaN
# 4       Broniatowski  NaN

# %% [markdown]
# ### 5. Extract edge lists

# %%
el = api.extract_el(activity)
el.head()
# Out:
#   author_id_from author_screen_name_from            status_id  \
# 0      195572533            Broniatowski  1356353645722394625
# 1      195572533            Broniatowski  1356284849070497792
# 2      195572533            Broniatowski  1338252088808267778
# 3      195572533            Broniatowski  1311857755502845955
# 4      195572533            Broniatowski  1296140059956174849
#
#                  to edge_type
# 0        Cincinnati   hashtag
# 1  vaccinehesitancy   hashtag
# 2           COVID19   hashtag
# 3    misinformation   hashtag
# 4          pandemic   hashtag

# %% [markdown]
# ### 6. Query seed and mentioned accounts for account info

# %%
seed_users = misinfo_researchers
print('seed user count: ' + str(len(seed_users)))
mentioned_users = el['to'][el['edge_type'] == 'mention'].unique().tolist()
print('mentioned user count: ' + str(len(mentioned_users)))
all_users = list(set(seed_users + mentioned_users))
print('total unique users: ' + str(len(all_users)))
# Out:
# seed user count: 41
# mentioned user count: 4371
# total unique users: 4372

# %%
#Add sleep since Twitter API rate limit is 900 user queries per 15 minutes
import time

counter = 0
all_users_df = []
for user in all_users:     
    try: 
        resp = api.get_users(usernames=user)        
        time.sleep(4)
        all_users_df.append(resp)         
    except:
        pass
    counter += 1
    if counter %250 == 0:
        print(str(counter) + ' out of ' + str(len(all_users)) + ' :: ' + user + ': ' + str(len(resp)))
        
all_users_df = pd.concat(all_users_df)    
all_users_df.reset_index(inplace = True, drop = True)
print(len(all_users_df))

# %% [markdown]
# ### 7. Write data to disc

# %%
# Write data to disc so I don't burn through all my queries
#all_users_df.to_csv('data/all_users.csv', index = False)
#activity.to_csv('data/activity.csv', index = False)
#el.to_csv('data/el.csv', index = False)
